# %%
import pandas as pd

# %%
filename = '../data/les-arbres.csv'

# ouvrir les fichier dans une dataframe 

df = pd.read_csv(filename, sep=";")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-63e8c3b41108> in <module>()
#       3 # ouvrir les fichier dans une dataframe
#       4
# ----> 5 df = pd.read_csv(filename, sep=";")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df.head()
# Out:
#      IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0  232702.0           Arbre  Alignement  PARIS 11E ARRDT               NaN
# 1  235862.0           Arbre  Alignement  PARIS 18E ARRDT               NaN
# 2  236391.0           Arbre  Alignement  PARIS 15E ARRDT                27
# 3  241122.0           Arbre  Alignement  PARIS 14E ARRDT               NaN
# 4   99927.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
#
#    NUMERO                      LIEU / ADRESSE IDEMPLACEMENT  \
# 0     NaN           BOULEVARD DE MENILMONTANT     000602002
# 1     NaN  AVENUE DE LA PORTE DE CLIGNANCOURT     000303007
# 2     NaN                 BOULEVARD GARIBALDI     000101024
# 3     NaN                        RUE SARRETTE     000501003
# 4     NaN                  JARDIN DU RANELAGH      00030007
#
#         LIBELLEFRANCAIS    GENRE       ESPECE VARIETEOUCULTIVAR  \
# 0               Sophora  Sophora     japonica               NaN
# ...

# %%
df['LIBELLEFRANCAIS'].value_counts()
# Out:
# Platane                 42565
# Marronnier              25231
# Tilleul                 21335
# Erable                  18403
# Sophora                 11798
# Frêne                    5171
# Pin                      4844
# Micocoulier              4201
# Chêne                    3866
# Cerisier à fleurs        3767
# Charme                   3472
# Poirier à fleurs         3409
# Noisetier de Byzance     3372
# Peuplier                 3314
# Robinier                 2306
# Bouleau                  2252
# Orme                     2070
# If                       1995
# Hêtre                    1926
# Paulownia                1413
# Fevier                   1394
# Faux-cyprès              1212
# Cyprès                   1205
# Noyer                    1130
# Tulipier                 1128
# Magnolia                 1127
# Cedrele                  1067
# Arbre de Judée           1019
# Pterocarya                997
# Prunier à fleurs          976
#                         ...
# ...

# %%
df[ df['LIBELLEFRANCAIS'] == 'Papayer'  ]
# Out:
#           IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT  \
# 141582  121739.0           Arbre      Jardin  PARIS 13E ARRDT
#
#        COMPLEMENTADRESSE  NUMERO     LIEU / ADRESSE IDEMPLACEMENT  \
# 141582               NaN     NaN  JARDIN PAUL NIZAN      00000015
#
#        LIBELLEFRANCAIS   GENRE  ESPECE VARIETEOUCULTIVAR  CIRCONFERENCEENCM  \
# 141582         Papayer  Carica  papaya               NaN               20.0
#
#         HAUTEUR (m) STADEDEVELOPPEMENT  REMARQUABLE  \
# 141582          3.0                NaN          NaN
#
#                         geo_point_2d
# 141582  48.8228009357, 2.35736984252

# %%
df['HAUTEUR (m)'].describe()
# Out:
# count    200332.000000
# mean         13.108235
# std        1970.258098
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          12.000000
# max      881818.000000
# Name: HAUTEUR (m), dtype: float64

# %%
# %matplotlib inline
df[df['HAUTEUR (m)'] < 30]['HAUTEUR (m)'].hist(bins=100)
